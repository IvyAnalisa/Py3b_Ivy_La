# %%
2. Read and explore data

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt



# Set default figure size for all plots
plt.rcParams['figure.figsize'] = [7, 5]

# Load the dataset
df = pd.read_csv('as6-iris-data.csv')  

# Inspect the dataset
print("First 5 rows \n",df.head())          # View the first 5 rows
print("First 10 rows \n",df.head(10))
print("  \n Dataset info:",df.info())          # Summary of the DataFrame
print("Sumary statistic: \n",df.describe())      # Statistics for numerical columns

print("\nShape of the DataFrame:", df.shape)

print("\nColumn Names:", df.columns)
print("\nData Types:\n", df.dtypes)
print("\nMissing Values:\n", df.isnull().sum())
print("\nUnique Values Per Column:\n", df.nunique())


# Select only numeric columns for correlation analysis
numeric_df = df.select_dtypes(include='number')
print("\nCorrelation Matrix:\n", numeric_df.corr())
# Out:
# First 5 rows
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# First 10 rows
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# ...

# %% [markdown]
# 3. Plotting the data

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt

# Set default figure size for all plots
plt.rcParams['figure.figsize'] = [7, 5]

# Load the dataset
df = pd.read_csv('as6-iris-data.csv')  
df.head()  # Default is 5 rows
df.head(10)  # To view the first 10 rows

species_dict = {
    'Iris-setosa': 0,
    'Iris-versicolor': 1,
    'Iris-virginica': 2
}
df['SpeciesNum'] = df['Species'].map(species_dict)
df.plot(
    kind='scatter',
    x='SepalLengthCm', 
    y='SepalWidthCm', 
    c='SpeciesNum', 
    cmap='viridis',
    colorbar=True,  # Ensures a colorbar is added
    title='Scatter Plot of Sepal Length vs Sepal Width'
)
plt.show()
